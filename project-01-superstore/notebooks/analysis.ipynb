# %% [markdown]
# # Superstore Analysis
#
# Analyzing sales data to understand business performance and identify opportunities

# %% [markdown]
# Checking the number of rows and columns to know how long the dataset is

# %% [markdown]
# Checking the datatypes to confirm that it match correctly, so we won't encounter problem in the future

# %% [markdown]
# Checking for missing values — missing data can distort analysis and lead to wrong business decisions

# %% [markdown]
# Checking where we are doing best so we work on our weaknesses too

# %% [markdown]
# Getting the unique customers to give them discount on next orders

# %%
import pandas as pd
import os

print(os.getcwd())

df = pd.read_csv('../data/Sample - Superstore.csv', encoding='latin-1')
# Q1 - Number of Rows and Cols
rows, cols = df.shape
print(f'Number of Rows: {rows}, Number of Columns: {cols}')
# Q2 - Data types of each column
print(df.dtypes)
# Q3 - Missing values in each column
print(df.isnull().values.any())
# Q4 - Category with highest Sales
print(df.groupby('Category')['Sales'].sum().sort_values(ascending=False))

# Q5 - Unique customers
print(df['Customer Name'].nunique())

# %%
import pandas as pd
import os

print(os.getcwd())

df = pd.read_csv('../data/Sample - Superstore.csv', encoding='latin-1')
# Q1 - Number of Rows and Cols
rows, cols = df.shape
print(f'Number of Rows: {rows}, Number of Columns: {cols}')
# Q2 - Data types of each column
print(df.dtypes)
# Q3 - Missing values in each column
print(df.isnull().values.any()) 
# Q4 - Category with highest Sales
print(df.groupby('Category')['Sales'].sum().sort_values(ascending=False))

# Q5 - Unique customers
print(df['Customer Name'].nunique())
# Out:
# c:\Users\HP\Documents\data-analyst-portfolio\project-01-superstore\notebooks
# Number of Rows: 9994, Number of Columns: 21
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object
# False
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64
# 793

# %% [markdown]
# Getting the unique customers to give them discount on next orders

# %% [markdown]
# Checking where we are doing best so we work on our weaknesses too

# %% [markdown]
# Checking for missing values — missing data can distort analysis and lead to wrong business decisions

# %% [markdown]
# Checking the datatypes to confirm that it match correctly, so we won't encounter problem in the future

# %% [markdown]
# Checking the number of rows and columns to know how long the dataset is
